# %%
import io
import base64
import torch
path = "saves/best_food.dat"
with open(path, 'rb') as f:
        raw_bytes = f.read()
        e = base64.encodebytes(raw_bytes)
        print(e)
# Out:
# b'
# ...
